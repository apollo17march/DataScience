# %%
import requests

# %%
url='http://www.mfd.gov.np'

# %%
req=requests.get(url)

# %%
req=requests.get('http://www.worldometers.info/world-population/')

# %%
req.headers
# Out:
# {'X-Powered-By': 'PHP/5.3.3', 'Transfer-Encoding': 'chunked', 'Set-Cookie': 'PHPSESSID=4h0uiu0bpf3sasknhqlu991a94; path=/', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Connection': 'close', 'Pragma': 'no-cache', 'Cache-Control': 'no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Date': 'Wed, 22 Jun 2016 01:54:10 GMT', 'Content-Type': 'text/html; charset=utf-8'}

# %%
from bs4 import BeautifulSoup

# %%
soup= BeautifulSoup()
# Out:
# C:\Users\Vamps\Anaconda2\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
import csv

# %%
import json

# %%
json.dump
# Out:
# <function json.dump>

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(req.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>\n<!--[if IE 8]> <html lang="en" class="ie8"> <![endif]--><!--[if IE 9]> <html lang="en" class="ie9"> <![endif]--><!--[if !IE]><!--> <html lang="en"> <!--<![endif]--> <head> <meta charset="unicode-escape"> <meta content="IE=edge" http-equiv="X-UA-Compatible"> <meta content="width=device-width, initial-scale=1" name="viewport"> <title>World Population Clock: 7.4 Billion People (2016) - Worldometers</title> <meta content="How many people are there in the world? World population has reached 7 billion. World population live counter with data sheets, graphs, maps, and census data regarding the current, historical, and future world population figures, estimates, growth rates, densities and demographics" name="description"><!-- Favicon --><link href="/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"><link href="/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"><link href="/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"><link h
# ...

# %%
table=soup.find('table',attrs={'id':'popbycountry'})

# %%
table
# Out:
# <table cellspacing="0" class="display compact nowrap table-list" id="popbycountry" width="100%"><thead> <tr> <th>#</th><th>Country (or dependency)</th><th>Population<br>(2016)</br></th><th>Yearly<br>Change</br></th><th>Net<br>Change</br></th><th>Density<br>(P/Km\xb2)</br></th> <th>Area<br>(Km\xb2)</br></th><th>Migrants<br>(net)</br></th><th>Fert.<br>Rate</br></th><th>Med.<br>Age</br></th><th>Urban<br>Pop %</br></th><th>World<br>Share</br></th> </tr></thead><tbody> <tr> <td>1</td> <td style="font-weight: bold; font-size:15px; text-align:left"><a href="/world-population/china-population/">China</a></td> <td style="font-weight: bold;">1,382,323,332</td> <td>0.46 %</td> <td>6,274,389</td> <td>147</td> <td>9,390,784</td> <td>-360,000</td> <td>1.55</td> <td>37</td> <td>57.9 %</td> <td>18.6 %</td> </tr> <tr> <td>2</td> <td style="font-weight: bold; font-size:15px; text-align:left"><a href="/world-population/india-population/">India</a></td> <td style="font-weight: bold;">1,326,801,576</td> 
# ...

# %%
headings= table.find('thead')

# %%
headings
# Out:
# <thead> <tr> <th>#</th><th>Country (or dependency)</th><th>Population<br>(2016)</br></th><th>Yearly<br>Change</br></th><th>Net<br>Change</br></th><th>Density<br>(P/Km\xb2)</br></th> <th>Area<br>(Km\xb2)</br></th><th>Migrants<br>(net)</br></th><th>Fert.<br>Rate</br></th><th>Med.<br>Age</br></th><th>Urban<br>Pop %</br></th><th>World<br>Share</br></th> </tr></thead>

# %%
names=headings.find_all('th')

# %%
names
# Out:
# [<th>#</th>,
#  <th>Country (or dependency)</th>,
#  <th>Population<br>(2016)</br></th>,
#  <th>Yearly<br>Change</br></th>,
#  <th>Net<br>Change</br></th>,
#  <th>Density<br>(P/Km\xb2)</br></th>,
#  <th>Area<br>(Km\xb2)</br></th>,
#  <th>Migrants<br>(net)</br></th>,
#  <th>Fert.<br>Rate</br></th>,
#  <th>Med.<br>Age</br></th>,
#  <th>Urban<br>Pop %</br></th>,
#  <th>World<br>Share</br></th>]

# %%
for tr
